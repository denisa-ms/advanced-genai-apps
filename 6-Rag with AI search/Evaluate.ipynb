# %% [markdown]
# # Evaluate your RAG

# %%
from dotenv import load_dotenv
import os

load_dotenv()
#create a .env file with the following variables and replace with your values
AISTUDIO_AZURE_OPENAI_KEY = os.getenv("AISTUDIO_AZURE_OPENAI_KEY")
AISTUDIO_AZURE_OPENAI_ENDPOINT = os.getenv("AISTUDIO_AZURE_OPENAI_ENDPOINT")
AISTUDIO_OPENAI_GPT4_DEPLOYMENT_NAME = os.getenv("AISTUDIO_OPENAI_GPT4_DEPLOYMENT_NAME")
AZURE_SUBSCRIPTION_ID = os.getenv("AZURE_SUBSCRIPTION_ID")
AZURE_AISTUDIO_PROJECT_RESOURCE_GROUP = os.getenv("AZURE_AISTUDIO_PROJECT_RESOURCE_GROUP")
AZURE_AISTUDIO_PROJECT_NAME = os.getenv("AZURE_AISTUDIO_PROJECT_NAME")
api_version = "2024-02-15-preview"

# %% [markdown]
# You can override configuration with `AzureOpenAIModelConfiguration` and `OpenAIModelConfiguration`.

# %%
from promptflow.core import AzureOpenAIModelConfiguration, OpenAIModelConfiguration

# override configuration with AzureOpenAIModelConfiguration - in this case I am using the same model just to show how to use it
configuration = AzureOpenAIModelConfiguration(
    azure_endpoint="${env:AISTUDIO_AZURE_OPENAI_ENDPOINT}",  # Use ${env:<ENV_NAME>} to surround the environment variable name.
    api_key="${env:AISTUDIO_AZURE_OPENAI_KEY}",
    azure_deployment="gpt-4",
)

# override configuration with OpenAIModelConfiguration
# configuration = OpenAIModelConfiguration(
#     base_url="${env:OPENAI_BASE_URL}",
#     api_key="${env:OPENAI_API_KEY}",
#     model="gpt-3.5-turbo"
# )

override_model = {"configuration": configuration, "parameters": {"max_tokens": 512}}

# %%
from promptflow.client import PFClient

pf = PFClient()

# %%
flow = "./prompts/basic.prompty"  # path to the prompty file
data = "./test-data/evaluation_dataset.jsonl"  # path to the data file

# create run with the flow and data
base_run = pf.run(
    flow=flow,
    data=data,
    column_mapping={
        "question": "${data.question}",
    },
    stream=True,
)
# Out:
# Starting prompt flow service...
# [2024-09-21 18:52:41 +0300][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run prompts_20240921_185230_058822, log path: C:\Users\dschlesinger\.promptflow\.runs\prompts_20240921_185230_058822\logs.txt
# You can stop the prompt flow service with the following command:'pf service stop'.
#
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=prompts_20240921_185230_058822
# 2024-09-21 18:52:41 +0300   55672 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2024-09-21 18:52:46 +0300   55672 execution.bulk     INFO     Current system's available memory is 17159.93359375MB, memory consumption of current process is 186.31640625MB, estimated available worker count is 17159.93359375/186.31640625 = 92
# 2024-09-21 18:52:46 +0300   55672 execution.bulk     INFO     Set process count to 4 by taking the minimum value among the factors of {'default_worker_count': 4, 'row_count': 13, 'estimated_worker_count_based_on_memory_usage': 92}.
# 2024-09-21 18:52:50 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-5)-Process id(45860)-Line number(0) start execution.
# 2024-09-21 18:52:50 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-3)-Process id(50132)-Line number(1) start execution.
# 2024-09-21 18:52:50 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(10864)-Line number(2) start execution.
# 2024-09-21 18:52:50 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-4)-Process id(55676)-Line number(3) start execution.
# 2024-09-21 18:52:52 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(10864)-Line number(2) completed.
# 2024-09-21 18:52:52 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(10864)-Line number(4) start execution.
# 2024-09-21 18:52:53 +0300   55672 execution.bulk     INFO     Finished 1 / 13 lines.
# 2024-09-21 18:52:53 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 3.03 seconds. Estimated time for incomplete lines: 36.36 seconds.
# 2024-09-21 18:52:54 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(10864)-Line number(4) completed.
# 2024-09-21 18:52:54 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(10864)-Line number(5) start execution.
# 2024-09-21 18:52:55 +0300   55672 execution.bulk     INFO     Finished 2 / 13 lines.
# 2024-09-21 18:52:55 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 2.52 seconds. Estimated time for incomplete lines: 27.72 seconds.
# 2024-09-21 18:52:57 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(10864)-Line number(5) completed.
# 2024-09-21 18:52:57 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(10864)-Line number(6) start execution.
# 2024-09-21 18:52:58 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-3)-Process id(50132)-Line number(1) completed.
# 2024-09-21 18:52:58 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-3)-Process id(50132)-Line number(7) start execution.
# 2024-09-21 18:52:58 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-5)-Process id(45860)-Line number(0) completed.
# 2024-09-21 18:52:58 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-5)-Process id(45860)-Line number(8) start execution.
# 2024-09-21 18:52:58 +0300   55672 execution.bulk     INFO     Finished 5 / 13 lines.
# 2024-09-21 18:52:58 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.61 seconds. Estimated time for incomplete lines: 12.88 seconds.
# 2024-09-21 18:52:59 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-4)-Process id(55676)-Line number(3) completed.
# 2024-09-21 18:52:59 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-4)-Process id(55676)-Line number(9) start execution.
# 2024-09-21 18:52:59 +0300   55672 execution.bulk     INFO     Finished 6 / 13 lines.
# 2024-09-21 18:52:59 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.51 seconds. Estimated time for incomplete lines: 10.57 seconds.
# 2024-09-21 18:53:00 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-5)-Process id(45860)-Line number(8) completed.
# 2024-09-21 18:53:00 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-5)-Process id(45860)-Line number(10) start execution.
# 2024-09-21 18:53:00 +0300   55672 execution.bulk     INFO     Finished 7 / 13 lines.
# 2024-09-21 18:53:00 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.44 seconds. Estimated time for incomplete lines: 8.64 seconds.
# 2024-09-21 18:53:00 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(10864)-Line number(6) completed.
# 2024-09-21 18:53:00 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(10864)-Line number(11) start execution.
# 2024-09-21 18:53:00 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-3)-Process id(50132)-Line number(7) completed.
# 2024-09-21 18:53:00 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-3)-Process id(50132)-Line number(12) start execution.
# 2024-09-21 18:53:01 +0300   55672 execution.bulk     INFO     Finished 9 / 13 lines.
# 2024-09-21 18:53:01 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.23 seconds. Estimated time for incomplete lines: 4.92 seconds.
# 2024-09-21 18:53:01 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-4)-Process id(55676)-Line number(9) completed.
# 2024-09-21 18:53:02 +0300   55672 execution.bulk     INFO     Finished 10 / 13 lines.
# 2024-09-21 18:53:02 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.21 seconds. Estimated time for incomplete lines: 3.63 seconds.
# 2024-09-21 18:53:03 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-3)-Process id(50132)-Line number(12) completed.
# 2024-09-21 18:53:03 +0300   55672 execution.bulk     INFO     Finished 11 / 13 lines.
# 2024-09-21 18:53:03 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.19 seconds. Estimated time for incomplete lines: 2.38 seconds.
# 2024-09-21 18:53:05 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(10864)-Line number(11) completed.
# 2024-09-21 18:53:05 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-5)-Process id(45860)-Line number(10) completed.
# 2024-09-21 18:53:06 +0300   55672 execution.bulk     INFO     Finished 13 / 13 lines.
# 2024-09-21 18:53:06 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.24 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2024-09-21 18:53:06 +0300   55672 execution.bulk     INFO     The thread monitoring the process [10864-SpawnProcess-2] will be terminated.
# 2024-09-21 18:53:06 +0300   55672 execution.bulk     INFO     The thread monitoring the process [55676-SpawnProcess-4] will be terminated.
# 2024-09-21 18:53:06 +0300   55672 execution.bulk     INFO     The thread monitoring the process [45860-SpawnProcess-5] will be terminated.
# 2024-09-21 18:53:06 +0300   55672 execution.bulk     INFO     The thread monitoring the process [50132-SpawnProcess-3] will be terminated.
# 2024-09-21 18:53:06 +0300   10864 execution.bulk     INFO     The process [10864] has received a terminate signal.
# 2024-09-21 18:53:06 +0300   55676 execution.bulk     INFO     The process [55676] has received a terminate signal.
# 2024-09-21 18:53:06 +0300   45860 execution.bulk     INFO     The process [45860] has received a terminate signal.
# 2024-09-21 18:53:06 +0300   50132 execution.bulk     INFO     The process [50132] has received a terminate signal.
# 2024-09-21 18:53:06 +0300   55672 execution.bulk     INFO     Process 45860 terminated.
# 2024-09-21 18:53:06 +0300   55672 execution.bulk     INFO     Process 55676 terminated.
# 2024-09-21 18:53:06 +0300   55672 execution.bulk     INFO     Process 10864 terminated.
# 2024-09-21 18:53:06 +0300   55672 execution.bulk     INFO     Process 50132 terminated.
# ======= Run Summary =======
#
# Run name: "prompts_20240921_185230_058822"
# Run status: "Completed"
# Start time: "2024-09-21 18:52:30.058822+03:00"
# Duration: "0:00:37.088619"
# Output path: "C:\Users\dschlesinger\.promptflow\.runs\prompts_20240921_185230_058822"

# %%
details = pf.get_details(base_run)
details.head(10)
# Out:
#                                      inputs.question  inputs.line_number  \
# 0                 Which tent is the most waterproof?                   0
# 1         Which camping table holds the most weight?                   1
# 2      How much does TrailWalker Hiking Shoes cost?                    2
# 3  What is the proper care for trailwalker hiking...                   3
# 4               What brand is for TrailMaster tent?                    4
# 5       How do I carry the TrailMaster tent around?                    5
# 6            What is the floor area for Floor Area?                    6
# 7   What is the material for TrailBlaze Hiking Pants                   7
# 8    What color does TrailBlaze Hiking Pants come in                   8
# 9  Cant he warrenty for TrailBlaze pants be trans...                   9
#
#                                       outputs.output
# 0  The most waterproof tent is subjective and can...
# 1  The weight capacity of camping tables varies b...
# 2  The price of TrailWalker Hiking Shoes can vary...
# 3  To care for trailwalker hiking shoes:\n\n1. Cl...
# 4  TrailMaster tents are a product of the brand O...
# 5  To carry the TrailMaster tent, first ensure it...
# 6  The term "floor area" can refer to several dif...
# 7  The material for TrailBlaze Hiking Pants can v...
# 8  The color options for TrailBlaze Hiking Pants ...
# 9  The transferability of a warranty for TrailBla...

# %%
eval_prompty = "./prompts/eval.prompty"

eval_run = pf.run(
    flow=eval_prompty,
    data="./test-data/evaluation_dataset.jsonl",  # path to the data file
    run=base_run,  # specify base_run as the run you want to evaluate
    column_mapping={
        "question": "${data.question}",
        "answer": "${run.outputs.output}",  
        "truth": "${data.ground_truth}",
    },
    stream=True,
)
# Out:
# [2024-09-21 20:36:48 +0300][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run prompts_20240921_203648_582918, log path: C:\Users\dschlesinger\.promptflow\.runs\prompts_20240921_203648_582918\logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=prompts_20240921_203648_582918
# 2024-09-21 20:36:48 +0300   55672 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2024-09-21 20:36:48 +0300   55672 execution.bulk     INFO     Current system's available memory is 18931.99609375MB, memory consumption of current process is 125.21875MB, estimated available worker count is 18931.99609375/125.21875 = 151
# 2024-09-21 20:36:48 +0300   55672 execution.bulk     INFO     Set process count to 4 by taking the minimum value among the factors of {'default_worker_count': 4, 'row_count': 13, 'estimated_worker_count_based_on_memory_usage': 151}.
# 2024-09-21 20:37:12 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-13)-Process id(54640)-Line number(0) start execution.
# 2024-09-21 20:37:12 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-12)-Process id(23816)-Line number(1) start execution.
# 2024-09-21 20:37:12 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-15)-Process id(58328)-Line number(2) start execution.
# 2024-09-21 20:37:12 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-14)-Process id(28144)-Line number(3) start execution.
# 2024-09-21 20:37:15 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-12)-Process id(23816)-Line number(1) completed.
# 2024-09-21 20:37:15 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-12)-Process id(23816)-Line number(4) start execution.
# 2024-09-21 20:37:15 +0300   55672 execution.bulk     INFO     Finished 1 / 13 lines.
# 2024-09-21 20:37:15 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 3.02 seconds. Estimated time for incomplete lines: 36.24 seconds.
# 2024-09-21 20:37:17 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-14)-Process id(28144)-Line number(3) completed.
# 2024-09-21 20:37:17 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-14)-Process id(28144)-Line number(5) start execution.
# 2024-09-21 20:37:17 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-12)-Process id(23816)-Line number(4) completed.
# 2024-09-21 20:37:17 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-12)-Process id(23816)-Line number(6) start execution.
# 2024-09-21 20:37:18 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-15)-Process id(58328)-Line number(2) completed.
# 2024-09-21 20:37:18 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-15)-Process id(58328)-Line number(7) start execution.
# 2024-09-21 20:37:18 +0300   55672 execution.bulk     INFO     Finished 4 / 13 lines.
# 2024-09-21 20:37:18 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.51 seconds. Estimated time for incomplete lines: 13.59 seconds.
# 2024-09-21 20:37:18 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-13)-Process id(54640)-Line number(0) completed.
# 2024-09-21 20:37:18 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-13)-Process id(54640)-Line number(8) start execution.
# 2024-09-21 20:37:19 +0300   55672 execution.bulk     INFO     Finished 5 / 13 lines.
# 2024-09-21 20:37:19 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.41 seconds. Estimated time for incomplete lines: 11.28 seconds.
# 2024-09-21 20:37:19 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-14)-Process id(28144)-Line number(5) completed.
# 2024-09-21 20:37:19 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-14)-Process id(28144)-Line number(9) start execution.
# 2024-09-21 20:37:20 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-12)-Process id(23816)-Line number(6) completed.
# 2024-09-21 20:37:20 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-12)-Process id(23816)-Line number(10) start execution.
# 2024-09-21 20:37:20 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-13)-Process id(54640)-Line number(8) completed.
# 2024-09-21 20:37:20 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-13)-Process id(54640)-Line number(11) start execution.
# 2024-09-21 20:37:20 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-15)-Process id(58328)-Line number(7) completed.
# 2024-09-21 20:37:20 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-15)-Process id(58328)-Line number(12) start execution.
# 2024-09-21 20:37:20 +0300   55672 execution.bulk     INFO     Finished 9 / 13 lines.
# 2024-09-21 20:37:20 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 0.9 seconds. Estimated time for incomplete lines: 3.6 seconds.
# 2024-09-21 20:37:21 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-14)-Process id(28144)-Line number(9) completed.
# 2024-09-21 20:37:22 +0300   55672 execution.bulk     INFO     Finished 10 / 13 lines.
# 2024-09-21 20:37:22 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.01 seconds. Estimated time for incomplete lines: 3.03 seconds.
# 2024-09-21 20:37:26 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-15)-Process id(58328)-Line number(12) completed.
# 2024-09-21 20:37:26 +0300   55672 execution.bulk     INFO     Finished 11 / 13 lines.
# 2024-09-21 20:37:26 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.28 seconds. Estimated time for incomplete lines: 2.56 seconds.
# 2024-09-21 20:37:26 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-12)-Process id(23816)-Line number(10) completed.
# 2024-09-21 20:37:27 +0300   55672 execution.bulk     INFO     Process name(SpawnProcess-13)-Process id(54640)-Line number(11) completed.
# 2024-09-21 20:37:27 +0300   55672 execution.bulk     INFO     Finished 13 / 13 lines.
# 2024-09-21 20:37:27 +0300   55672 execution.bulk     INFO     Average execution time for completed lines: 1.16 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2024-09-21 20:37:27 +0300   55672 execution.bulk     INFO     The thread monitoring the process [28144-SpawnProcess-14] will be terminated.
# 2024-09-21 20:37:27 +0300   55672 execution.bulk     INFO     The thread monitoring the process [23816-SpawnProcess-12] will be terminated.
# 2024-09-21 20:37:27 +0300   55672 execution.bulk     INFO     The thread monitoring the process [54640-SpawnProcess-13] will be terminated.
# 2024-09-21 20:37:27 +0300   55672 execution.bulk     INFO     The thread monitoring the process [58328-SpawnProcess-15] will be terminated.
# 2024-09-21 20:37:27 +0300   28144 execution.bulk     INFO     The process [28144] has received a terminate signal.
# 2024-09-21 20:37:27 +0300   54640 execution.bulk     INFO     The process [54640] has received a terminate signal.
# 2024-09-21 20:37:27 +0300   58328 execution.bulk     INFO     The process [58328] has received a terminate signal.
# 2024-09-21 20:37:27 +0300   23816 execution.bulk     INFO     The process [23816] has received a terminate signal.
# 2024-09-21 20:37:28 +0300   55672 execution.bulk     INFO     Process 28144 terminated.
# 2024-09-21 20:37:28 +0300   55672 execution.bulk     INFO     Process 58328 terminated.
# 2024-09-21 20:37:28 +0300   55672 execution.bulk     INFO     Process 23816 terminated.
# 2024-09-21 20:37:28 +0300   55672 execution.bulk     INFO     Process 54640 terminated.
# ======= Run Summary =======
#
# Run name: "prompts_20240921_203648_582918"
# Run status: "Completed"
# Start time: "2024-09-21 20:36:48.582918+03:00"
# Duration: "0:00:39.643578"
# Output path: "C:\Users\dschlesinger\.promptflow\.runs\prompts_20240921_203648_582918"

# %%
details = pf.get_details(eval_run)
details.head(10)
# Out:
#                                      inputs.question  \
# 0                 Which tent is the most waterproof?
# 1         Which camping table holds the most weight?
# 2      How much does TrailWalker Hiking Shoes cost?
# 3  What is the proper care for trailwalker hiking...
# 4               What brand is for TrailMaster tent?
# 5       How do I carry the TrailMaster tent around?
# 6            What is the floor area for Floor Area?
# 7   What is the material for TrailBlaze Hiking Pants
# 8    What color does TrailBlaze Hiking Pants come in
# 9  Cant he warrenty for TrailBlaze pants be trans...
#
#                                        inputs.answer  \
# 0  The most waterproof tent is subjective and can...
# 1  The weight capacity of camping tables varies b...
# 2  The price of TrailWalker Hiking Shoes can vary...
# 3  To care for trailwalker hiking shoes:\n\n1. Cl...
# 4  TrailMaster tents are a product of the brand O...
# 5  To carry the TrailMaster tent, first ensure it...
# 6  The term "floor area" can refer to several dif...
# 7  The material for TrailBlaze Hiking Pants can v...
# 8  The color options for TrailBlaze Hiking Pants ...
# 9  The transferability of a warranty for TrailBla...
#
#                                  inputs.ground_truth  \
# 0  The Alpine Explorer Tent has the highest rainf...
# 1  The Adventure Dining Table has a higher weight...
# 2                                               $110
# 3  After each use, remove any dirt or debris by b...
# 4                                      OutdoorLiving
# 5   Carry bag included for convenient storage and...
# 6                                     80 square feet
# 7                  Made of high-quality nylon fabric
# 8                                              Khaki
# 9  he warranty is non-transferable and applies on...
#
#                                         inputs.truth  inputs.line_number  \
# 0  The Alpine Explorer Tent has the highest rainf...                   0
# 1  The Adventure Dining Table has a higher weight...                   1
# 2                                               $110                   2
# 3  After each use, remove any dirt or debris by b...                   3
# 4                                      OutdoorLiving                   4
# 5   Carry bag included for convenient storage and...                   5
# 6                                     80 square feet                   6
# 7                  Made of high-quality nylon fabric                   7
# 8                                              Khaki                   8
# 9  he warranty is non-transferable and applies on...                   9
#
#    outputs.score                                outputs.explanation
# 0              4  The answer provides a detailed explanation of ...
# 1              4  The answer provides a useful range and suggest...
# 2              4  The answer provides a comprehensive explanatio...
# 3              5  The answer provides comprehensive care instruc...
# 4              2  TrailMaster is not a known product line of Oza...
# 5              4  The answer provides a general method for carry...
# 6              4  The answer correctly explains that 'floor area...
# 7              3  The answer provides a general description of m...
# 8              4  The answer provides a helpful direction to fin...
# 9              4  The answer provides a comprehensive response t...

# %%
# visualize run using ui
pf.visualize([base_run, eval_run])
# Out:
# Prompt flow service has started...
# The HTML file is generated at 'C:\\Users\\dschlesinger\\AppData\\Local\\Temp\\pf-visualize-detail-0yr5vf3p.html'.
# Trying to view the result in a web browser...
# Successfully visualized from the web browser.
